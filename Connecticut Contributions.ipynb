# %%
import pandas as pd

# %%
CandReceipts = pd.read_csv("http://seec.ct.gov/ecrisreporting/Data/eCrisDownloads/exportdatafiles/Receipts2017ElectionYearCandidateExploratoryCommittees.csv")

# %%
CandReceipts.head()
# Out:
#       Committee Contributor Name  District   Office Sought           Employer  \
# 0  Berriault 17       Minh Huynh       NaN  Common Council                NaN
# 1  Berriault 17   Greg Gerratana       NaN  Common Council  Nutmeg Strategies
# 2  Berriault 17     Hosea Baskin       NaN  Common Council            Student
# 3  Berriault 17    Shari Guarino       NaN  Common Council                NaN
# 4  Berriault 17    Elaine Sisson       NaN  Common Council            Retired
#
#                               Receipt Type       Committee Type  \
# 0  Itemized Contributions from Individuals  Candidate Committee
# 1  Itemized Contributions from Individuals  Candidate Committee
# 2  Itemized Contributions from Individuals  Candidate Committee
# 3  Itemized Contributions from Individuals  Candidate Committee
# 4  Itemized Contributions from Individuals  Candidate Committee
#
#   Transaction Date File To State  Amount        ...         \
# ...

# %%
CandReceipts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3770 entries, 0 to 3769
# Data columns (total 24 columns):
# Committee                        3770 non-null object
# Contributor Name                 3763 non-null object
# District                         3289 non-null float64
# Office Sought                    3770 non-null object
# Employer                         3450 non-null object
# Receipt Type                     3770 non-null object
# Committee Type                   3770 non-null object
# Transaction Date                 3770 non-null object
# File To State                    3770 non-null object
# Amount                           3770 non-null float64
# Receipt State                    3770 non-null object
# Occupation                       3299 non-null object
# ElectionYear                     3770 non-null int64
# Contractor Executive Branch      9 non-null object
# Contractor Legislative Branch    9 non-null object
# ...

# %%
CandDis = pd.read_csv("http://seec.ct.gov/ecrisreporting/Data/eCrisDownloads/exportdatafiles/Disbursements2017ElectionYearCandidateExploratoryCommittees.csv")

# %%
CandDis.head()
# Out:
#       Committee       Committee Type          Payee  \
# 0  Berriault 17  Candidate Committee        NGP VAN
# 1  Berriault 17  Candidate Committee   Day Campaign
# 2  Berriault 17  Candidate Committee        NGP VAN
# 3  Berriault 17  Candidate Committee  Stop and Shop
# 4  Berriault 17  Candidate Committee  Stop and Shop
#
#                               Purpose of Expenditure  \
# 0  Misc *(Miscellaneous expenditure for which no ...
# 1     BNK(Bank fees, interest charges, or penalties)
# 2  Misc *(Miscellaneous expenditure for which no ...
# 3                                      POST(Postage)
# 4  FNDR *(Expenses associated with holding a comm...
#
#                   Description             Payment Method Payment Date  Amount  \
# 0          NGP VAN Access fee  Electronic Funds Transfer     2/1/2017  150.00
# 1  Credit Card Processing fee  Electronic Funds Transfer     3/1/2017   15.00
# 2      NGP VAN Processing fee  Electronic Funds Transfer     3/1/2017  150.00
# ...

# %%
CandDis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 19 columns):
# Committee                 421 non-null object
# Committee Type            421 non-null object
# Payee                     421 non-null object
# Purpose of Expenditure    421 non-null object
# Description               394 non-null object
# Payment Method            421 non-null object
# Payment Date              421 non-null object
# Amount                    421 non-null float64
# File to State             421 non-null object
# Period Start              421 non-null object
# Period End                421 non-null object
# Election Year             421 non-null int64
# Status                    421 non-null object
# Data Source               421 non-null object
# Refiled Electronically    421 non-null object
# Street Address            421 non-null object
# City                      421 non-null object
# State                     421 non-null object
# ...
